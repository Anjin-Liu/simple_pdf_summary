# %% [markdown]
# To play around with this simple pdf report generator, please follow the following 4 steps
# 1. Use conda to create a new venv
# 2. Install required python packages
# 3. Add LLM api token into credentials/llm-cred.json
# 4. Config your LLM embedding model and LLM chat model
# 5. Run the step scripts
#
# The overall workflow of this project ![alt text](asset/simple_pdf_generation.png)

# %%
# !pip install -r requirements

# %%
# !python -m step.s01_extract_pdf_text --file_name test_1
# Out:
# {'file_name': 'test_1'}
# # ======================================== #
# # Step 1. Extracting text from PDF         #
# # ======================================== #
# # ======================================== #
# # Step 2. Preprocessing raw text           #
# # ======================================== #
# # ======================================== #
# # Step 3. Segment preprocessed text        #
# # ======================================== #
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736898806.580642   46843 init.cc:232] grpc_wait_for_shutdown_with_timeout() timed out.

# %%
# !python -m step.s03_llm_chunk_and_indexing --file_name test_1
# Out:
# {'file_name': 'test_1'}
# # ======================================== #
# # Step 1. Chunk and Indexing               #
# # ======================================== #
# Indexed 5 chunks into Chroma database '/home/jupyter/pdf_summary/data/04_indexed_vector_data/test_1.chroma_db'
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736898866.755769   48060 init.cc:232] grpc_wait_for_shutdown_with_timeout() timed out.

# %%
# !python -m step.s04_llm_report_geneartion --file_name test_1
# Out:
# {'file_name': 'test_1'}
# # ======================================== #
# # Step 1. Load indexed preprocessed text   #
# # ======================================== #
# # ======================================== #
# # Step 2. Query revenue, net income etc.   #
# # ======================================== #
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736898915.450016   48264 init.cc:232] grpc_wait_for_shutdown_with_timeout() timed out.

# %% [markdown]
# # The outputs of step 1 which segmented by a horizontal line
#
# Statement of comprehensive income
# For the year ended 30 June
#
# | Notes | Last Year ($) | Previous Year ($) |
# |---|---|---|
# | **Revenue** |  |  |
# | Membership subscriptions | 6,748,000 | 6,571,000 |
# | Interest | 251,000 | 231,000 |
# | Rental income | 185,000 | 244,000 |
# | Other revenue 3A | 613,000 | 655,000 |
# | **Total revenue** | **7,797,000** | **7,701,000** |
# | **Expenses** |  |  |
# | Employee expenses 4A | 3,167,000 | 3,023,000 |
# | Capitation fees 4B | 830,000 | 823,000 |
# | Affiliation fees 4C | 228,000 | 231,000 |
# | Depreciation 4D | 97,000 | 88,000 |
# | Administration expenses 4E | 1,649,000 | 1,475,000 |
# | Legal costs 4F | 296,000 | 62,000 |
# | Donations 4G | 77,000 | 120,000 |
# | Motor vehicle expenses 4H | 89,000 | 79,000 |
# | Other expenses 4I | 835,000 | 775,000 |
# | **Total expenses** | **7,268,000** | **6,676,000** |
# | **Surplus (deficit) for the year** | **529,000** | **1,025,000** |
# | Other comprehensive income |  |  |
# | Gain on revaluation – investment property | - | 342,000 |
# | **Total comprehensive income for the year** | **529,000** | **1,367,000** |
#
# The above statement should be read in conjunction with the notes.
#
# -------------------------------------------------
#
# Statement of financial position
# As at 30 June
#
# | Notes | Last Year ($) | Previous Year ($) |
# |---|---|---|
# | **ASSETS** | | |
# | **Current Assets** | | |
# | Cash and cash equivalents 5A | 3,093,000 | 4,955,000 |
# | Trade and other receivables 5B | 528,000 | 226,000 |
# | Other current assets 5C | 408,000 | 383,000 |
# | **Total Current Assets** | **4,029,000** | **5,564,000** |
# | **Non-Current Assets** | | |
# | Land and buildings 6A | 10,000,000 | - |
# | Plant and equipment 6B | 104,000 | 132,000 |
# | Motor vehicles 6C | 141,000 | 147,000 |
# | Investment property 6D | 2,170,000 | 2,000,000 |
# | **Total Non-Current Assets** | **12,415,000** | **2,279,000** |
# | **TOTAL ASSETS** | **16,444,000** | **7,843,000** |
# | **LIABILITIES** | | |
# | **Current Liabilities** | | |
# | Trade and other payables 7A | 337,000 | 244,000 |
# | Employee provisions 7B | 520,000 | 556,000 |
# | **Total Current Liabilities** | **857,000** | **800,000** |
# | **Non-Current Liabilities** | | |
# | Borrowings 8A | 8,000,000 | - |
# | Employee provisions 7B | 140,000 | 125,000 |
# | **Total Non-Current Liabilities** | **8,140,000** | **125,000** |
# | **TOTAL LIABILITIES** | **8,997,000** | **925,000** |
# | **NET ASSETS** | **7,447,000** | **6,918,000** |
# | **EQUITY** | | |
# | Retained earnings | 7,105,000 | 6,576,000 |
# | Reserves | 342,000 | 342,000 |
# | **TOTAL EQUITY** | **7,447,000** | **6,918,000** |
#
# The above statement should be read in conjunction with the notes.
#
# -------------------------------------------------
#
# Statement of changes in equity
# For the year ended 30 June
#
# |  | Asset Revaluation Reserve ($) | Retained Earnings ($) | Total ($) |
# |---|---|---|---|
# | Balance as at 1 July previous year | - | 6,186,000 | 5,209,000 |
# | Revaluation increment | 342,000 | - | 342,000 |
# | Profit for the year | - | 1,367,000 | 1,367,000 |
# | Closing balance as at 30 June previous year | 342,000 | 6,576,000 | 6,918,000 |
# | Revaluation increment | - | - | - |
# | Profit for the year | - | 529,000 | 529,000 |
# | Closing balance as at 30 June last year | 342,000 | 7,105,000 | 7,447,000 |
#
#
# The above statement should be read in conjunction with the notes.
#
# -------------------------------------------------
#
# Statement of cash flows
# For the year ended 30 June
#
# | Notes | Last Year ($) | Previous Year ($) |
# |---|---|---|
# | **CASH FLOWS FROM OPERATING ACTIVITIES** | | |
# | **Cash Received** | | |
# | Receipts from members | 7,007,000 | 6,903,000 |
# | Interest | 251,000 | 231,000 |
# | Rental | 314,000 | 379,000 |
# | Other | 373,000 | 294,000 |
# | **Total Cash Received** | **7,945,000** | **7,807,000** |
# | **Cash Used** | | |
# | Employees | (2,824,000) | (2,695,000) |
# | Suppliers | (4,585,000) | (4,210,000) |
# | **Total Cash Used** | **(7,409,000)** | **(6,905,000)** |
# | **NET CASH FROM OPERATING ACTIVITIES** | **536,000** | **902,000** |
# | **INVESTING ACTIVITIES** | | |
# | **Cash Received** | | |
# | Proceeds from sale of plant and equipment | 9,000 | 56,000 |
# | **Total Cash Received** | **9,000** | **56,000** |
# | **Cash Used** | | |
# | Purchase of land and buildings | (10,000,000) | - |
# | Purchase of plant and equipment | (234,000) | (156,000) |
# | Purchase of investments | (173,000) | - |
# | **Total Cash Used** | **(10,407,000)** | **(156,000)** |
# | **NET CASH FROM INVESTING ACTIVITIES** | **(10,398,000)** | **(100,000)** |
# | **FINANCING ACTIVITIES** | | |
# | **Cash Received** | | |
# | Borrowings | 8,000,000 | - |
# | **Total Cash Received** | **8,000,000** | **-** |
# | **Cash Used** | | |
# | Repayment of borrowings | - | - |
# | **Total Cash Used** | **-** | **-** |
# | **NET CASH FROM FINANCING ACTIVITIES** | **8,000,000** | **-** |
# | **NET INCREASE/(DECREASE) IN CASH HELD** | **(1,862,000)** | **802,000** |
# | Cash and cash equivalents at the beginning of the reporting period | 4,955,000 | 4,153,000 |
# | Cash and cash equivalents at the end of the reporting period 5A | 3,093,000 | 4,955,000 |
#
# The above statement should be read in conjunction with the notes.

# %% [markdown]
# # The output of step 4
# ## Financial Summary Report
#
# This report analyzes the financial health of the company based on the provided financial statements for the year ended June 30th, comparing the last year's performance to the previous year.
#
# **Key Highlights:**
#
# * **Significant Asset Growth:** Total assets more than doubled, increasing from $7.84 million to $16.44 million, primarily driven by the acquisition of land and buildings ($10 million) and an increase in investment property.
# * **Increased Liabilities:** Total liabilities also saw a substantial rise, from $0.93 million to $9 million, mainly due to new borrowings of $8 million.
# * **Profitability Decline:** While the company remains profitable, the surplus for the year decreased significantly from $1.03 million to $0.53 million. This is despite a slight increase in revenue.
# * **Negative Cash Flow from Operations:** Net cash from operating activities decreased from $0.90 million to $0.54 million.
# * **Heavy Investment Activity:**  Significant cash outflow from investing activities ($10.40 million) reflects the substantial investment in land and buildings.
# * **Reliance on Financing:** The company relied heavily on borrowings ($8 million) to finance its investing activities.
#
#
# **Detailed Analysis:**
#
# **1. Profitability:**
#
# * **Revenue:** Total revenue increased marginally from $7.70 million to $7.80 million.  While membership subscriptions, interest income, and other revenue saw slight increases, rental income decreased.
# * **Expenses:** Total expenses increased significantly from $6.68 million to $7.27 million. Key drivers include increases in employee expenses, administration expenses, legal costs, and other expenses.  The decrease in donations helped offset some of these increases.
# * **Net Surplus:** The combined effect of marginally increased revenue and significantly increased expenses resulted in a substantial decrease in the surplus from $1.03 million to $0.53 million. This warrants further investigation into cost control measures.
#
# **2. Liquidity and Solvency:**
#
# * **Current Ratio:** The current ratio (current assets / current liabilities) decreased from 7.0 to 4.7. This indicates a reduced ability to meet short-term obligations. While current assets decreased, current liabilities increased, contributing to this decline.
# * **Debt-to-Equity Ratio:** The debt-to-equity ratio (total liabilities / total equity) increased significantly from 0.13 to 1.21. This indicates a much higher reliance on debt financing, which increases financial risk. The $8 million in borrowings is the primary driver.
# * **Cash Flow:** The company experienced a net decrease in cash and cash equivalents of $1.86 million. While operating activities generated positive cash flow, it was insufficient to cover the significant cash outflow from investing activities. Financing activities, primarily the $8 million borrowing, bridged the gap.
#
# **3. Asset Management:**
#
# * **Significant Investment in Fixed Assets:** The acquisition of land and buildings represents a substantial investment in non-current assets. This should contribute to future revenue generation but also carries the burden of depreciation and potential risks associated with property ownership.
# * **Decrease in Current Assets:** The decrease in cash and cash equivalents and a relatively small increase in receivables contributed to the overall decline in current assets.
#
# **4. Equity:**
#
# * **Retained Earnings:** Retained earnings increased from $6.58 million to $7.11 million, reflecting the current year's profit.
# * **Reserves:** The asset revaluation reserve remained unchanged at $0.34 million.  The significant gain on revaluation of investment property in the previous year contributed to this reserve.
#
#
# **Overall Assessment:**
#
# The company has experienced significant growth in assets, funded primarily through debt. While profitability remains positive, the declining surplus and increasing expenses raise concerns. The significant decrease in the current ratio and the substantial increase in the debt-to-equity ratio indicate increased financial risk.  Management should focus on improving operational efficiency, controlling costs, and carefully managing its debt levels to ensure long-term financial sustainability.  Further analysis is needed to understand the reasons behind the increased expenses and the strategic rationale for the significant investment in land and buildings.  Monitoring the return on this investment will be crucial in the coming years.
